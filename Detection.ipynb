# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15927, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 15927 (delta 21), reused 30 (delta 13), pack-reused 15880
# Receiving objects: 100% (15927/15927), 14.66 MiB | 18.46 MiB/s, done.
# Resolving deltas: 100% (10920/10920), done.

# %%
# !python "/content/yolov5/detect.py" --weights "/content/Smoke.pt" --img 640 --conf 0.25 --source "/content/istockphoto-1352957134-640_adpp_is.mp4"
# Out:
# detect: weights=['/content/Smoke.pt'], source=/content/istockphoto-1352957134-640_adpp_is.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# video 1/1 (1/1251) /content/istockphoto-1352957134-640_adpp_is.mp4: 384x640 1 cige, 44.4ms
# video 1/1 (2/1251) /content/istockphoto-1352957134-640_adpp_is.mp4: 384x640 1 cige, 7.8ms
# video 1/1 (3/1251) /content/istockphoto-1352957134-640_adpp_is.mp4: 384x640 1 cige, 7.9ms
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics
# !cd ultralytics
# !pip install -e ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# Obtaining file:///content/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.167
#     Uninstalling ultralytics-8.0.167:
#       Successfully uninstalled ultralytics-8.0.167
#   Running setup.py develop for ultralytics
# ...

# %%
# !yolo predict model="/content/Fire.pt" source='/content/testing.mp4'
# Out:
# Ultralytics YOLOv8.0.167 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients
#
# video 1/1 (1/309) /content/testing.mp4: 384x640 1 No-fire, 104.0ms
# video 1/1 (2/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (3/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (4/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (5/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (6/309) /content/testing.mp4: 384x640 2 No-fires, 11.0ms
# video 1/1 (7/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (8/309) /content/testing.mp4: 384x640 2 No-fires, 11.1ms
# video 1/1 (9/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (10/309) /content/testing.mp4: 384x640 1 No-fire, 11.0ms
# video 1/1 (11/309) /content/testing.mp4: 384x640 2 No-fires, 11.0ms
# video 1/1 (12/309) /content/testing.mp4: 384x640 2 No-fires, 11.0ms
# ...
